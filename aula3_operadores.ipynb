# %% [markdown]
# ## Operadores Aritméticos

# %%
# Soma
print(3 + 2)
# Out:
# 5

# %%
# Subtração: Também podemos usar variáveis pra isso
price = 20
discount = 4
final_price = price - discount
print(final_price)
# Out:
# 16

# %%
# Multiplicação
print(10 * 10)
# Out:
# 100

# %%
# Divisão: Se a operação de divisão for realizada com uma barra /, o valor resultante será um número de ponto flutuante (float).
print(5 / 2)
# Out:
# 2.5

# %%
# Divisão inteira: Se a operação de divisão for realizada com duas barras //, o valor resultante será um número inteiro (int).
# O valor será truncado, ou seja, as casas decimais serão ignoradas.

print(5//2)
# Out:
# 2

# %%
#Resto da Divisão: Se a operação de divisão for realizada com o operador %, teremos o resto de uma divisão entre números inteiros.
print(5%2)
# Out:
# 1

# %% [markdown]
# Imagine que você está desenvolvendo um site e tem 43 produtos para exibir. Cada página do site suporta apenas 10 produtos.
#
# Quantas páginas completas você terá? 43 // 10 = 4 páginas.
#
# Quantos produtos sobrarão para a última página (incompleta)? 43 % 10 = 3 produtos.

# %%
print(43/10)
print(43//10)
print(43%10)
# Out:
# 4.3
# 4
# 3

# %%
#Também posso fazer operações matemáticas a partir de números inputados pelo usuário
n1 = int(input('Digite um número: '))
n2 = int(input('Digite mais um número: '))
final_sum = n1 + n2
print(f'{n1} + {n2} é igual à {final_sum}.')
# Out:
# Digite um número: 5
# Digite mais um número: 10
# 5 + 10 é igual à 15.

# %%
# Também podemos alterar os tipos para outros
age = int(input('Digite sua idade: '))
name = str(input('Digite seu nome: '))
height = float(input('Digite sua altura: '))
print(f'Seu nome é {age}, sua idade é {age} e sua altura é {height}')
# Out:
# Digite sua idade29
# Digite seu nomeMaria
# Digite sua altura:1.66
# Seu nome é Maria, sua idade é 29 e sua altura é 1.66

# %% [markdown]
# Momento exercício: 5min
# Faça um programa que leia/receba a entrada de um número inteiro e mostre na tela o seu sucessor e seu antecessor.
# Exemplo de mensagem de retorno: O antecessor do número 5 é 4 e o sucessor é 6.

# %%
num = int(input('Digite um número: '))
antecessor = num - 1
sucessor = num + 1

print('O antecessor do número {} é {} e o sucessor é {}'.format(num, antecessor, sucessor))

# %% [markdown]
# Momento exercício: 5min
# Escreva um programa que pergunte a quantidade de Km percorridos por um carro alugado e a quantidade de dias pelos quais ele foi alugado.
#
# Calcule o preço a pagar, sabendo que o carro custa 80 reais por dia e 0.20 reais (20 centavos) por Km rodado.

# %%
km = float(input('Quantos km foram percorridos? '))
days = int(input('Por quantos dias o carro foi alugado? '))

price = (days * 80) + (km * 0.20)
print(f'O preço a pagar é de {price} reais')
# Out:
# Quantos km foram percorridos? 5
# Por quantos dias o carro foi alugado? 20
# O preço a pagar é de 1601.0 reais

# %% [markdown]
# ## Precedência entre operadores (slides)

# %%
2 + 3 * 4 / (4 - 2)
# Out:
# 8.0

# %%
(2 + 3) * 4 / ( 4 - 2 )
# Out:
# 10.0

# %%
(2 + (3 * 4)) / ( 4 - 2 )
# Out:
# 7.0

# %% [markdown]
# ## Operadores Relacionais

# %%
estoque = 50
pedido = 60

print(pedido > estoque)   # True (Estoque insuficiente)
print(pedido == estoque)  # False (Não é a quantidade exata)
# Out:
# True
# False

# %%
# Exemplo validando se o aluno passou de ano
nota = float(input("Digite a nota do aluno (0-100): "))
# Se fosse um programa real, poderia percorrer uma coluna de uma tabela com as notas dos alunos (aprenderemos isso em estruturas de repetição)

# 1. Verificação de Intervalo (Nota entre 0 e 10)
# Podemos usar a sintaxe encadeada do Python ou o operador 'and'
verifica_nota = (nota >= 60)

# 2. Verificação de Nota Máxima
nota_maxima = (nota == 10)

# Saída de resultados (Booleanos)
print(f"Passou? {verifica_nota}")
print(f"O aluno tirou a nota máxima? {nota_maxima}")
# Out:
# Digite a nota do aluno (0-100): 60
# Passou? True
# O aluno tirou a nota máxima? False

# %% [markdown]
# Exercício 5min:
# Defina as variáveis stored_user = "admin" e stored_password = "1234".
# Peça para o usuário digitar um login e uma senha (use as funções de input).
# Use operadores relacionais para exibir True se o acesso for permitido (ou seja, se o usuário for admin) e False caso contrário.
# Não é necessário usar condicionais if e else ainda, use apenas os operadores relacionais.

# %%
# System registered data
stored_user = "admin"
stored_password = "1234"

# User input
input_user = input("Enter username: ")
input_password = input("Enter password: ")

is_user_correct = (input_user == stored_user)
is_password_correct = (input_password == stored_password)

# Output
print("-" * 20)
print(f"Username recognized? {is_user_correct}")
print(f"Password recognized? {is_password_correct}")
# Out:
# Enter username: admin
# Enter password: 1234
# --------------------
# Username recognized? True
# Password recognized? True

# %% [markdown]
# ## Operadores Lógicos

# %%
# Exemplo 1: Verificação de bônus salarial
salary = 3000
years_at_company = 5

# Regra: Salário menor que 5000 E mais de 3 anos de casa
has_bonus = (salary < 5000) and (years_at_company > 3)
print(f"Qualified for bonus? {has_bonus}") # True
# Out:
# Qualified for bonus? True

# %%
# Exemplo 2: Acesso ao sistema (Multi-fator)
has_keycard = False
has_fingerprint = True

# Regra: Entra se tiver o cartão OU a digital
can_enter = has_keycard or has_fingerprint
print(f"Can enter building? {can_enter}") # True
# Out:
# Can enter building? True

# %%
# System registered data
stored_user = "admin"
stored_password = "1234"

# User input
input_user = input("Enter username: ")
input_password = input("Enter password: ")

# Authentication Logic
# Access is True only if BOTH username AND password are correct
is_access_granted = (input_user == stored_user) and (input_password == stored_password)


# Output
print("-" * 20)
print(f"Access granted? {is_access_granted}")
# Out:
# Enter username: admin
# Enter password: 1234
# --------------------
# Access granted? True

# %%
# --- CONFIGURAÇÃO DOS FILTROS (Simulando o clique do usuário no site) ---
is_hotel = True
is_apart_hotel = False
is_near_airport = False

hotel = 'Hotel Colina das Montanhas'

# --- 1. LÓGICA DE FILTRO (Operadores Lógicos e Relacionais) ---
# A acomodação serve se: (É Hotel OU Apart) E (Perto do Aeroporto)
matches_search_criteria = (is_hotel or is_apart_hotel) and is_near_airport

# --- 2. EXIBIÇÃO ---
print(f"Exibir {hotel} para o usuário? {matches_search_criteria}")
# Out:
# Exibir Hotel Colina das Montanhas para o usuário? False

# %%
import ipywidgets as widgets
from IPython.display import display

# Dados fixos do Hotel (O que ele oferece)
hotel_name = 'Hotel Colina das Montanhas'
hotel_is_near_airport = False
hotel_is_hotel_type = True

# --- 1. TÍTULO ORGANIZADO ---
print("==========================================")
print("      SISTEMA DE BUSCA: HOTEL EXPLORER     ")
print("==========================================")
print("Selecione o que você deseja encontrar:")

# --- 2. INTERFACE (WIDGETS) ---
# O usuário marca o que ele PROCURA
user_wants_hotel = widgets.Checkbox(description='Quero Hotel')
user_wants_airport = widgets.Checkbox(description='Quero perto do Aeroporto')

interface_ui = widgets.VBox([user_wants_hotel, user_wants_airport])
search_button = widgets.Button(description="Buscar", button_style='primary')
output_area = widgets.Output()

# --- 3. LÓGICA DE COMPARAÇÃO (OPERADORES) ---
def check_compatibility(b):
    with output_area:
        output_area.clear_output()

        # Comparando o desejo do usuário com a realidade do hotel
        # 1. Ele quer hotel? O hotel é hotel?
        check_type = (user_wants_hotel.value == hotel_is_hotel_type)

        # 2. Ele quer aeroporto? O hotel é perto?
        # (Aqui usamos a lógica de igualdade: False == False dá True!)
        check_airport = (user_wants_airport.value == hotel_is_near_airport)

        # O resultado final só é True se TODOS os filtros baterem com a realidade
        is_match = check_type and check_airport

        # --- EXIBIÇÃO ---
        print(f"\n🏨 Hotel Analisado: {hotel_name}")
        print("-" * 42)
        print(f"As preferências batem com este hotel? {is_match}")
        print("-" * 42)
        print(f"Desejo do usuário vs Realidade:")
        print(f"- Tipo Correto? {check_type}")
        print(f"- Localização Correta? {check_airport}")

search_button.on_click(check_compatibility)
display(interface_ui, search_button, output_area)
# Out:
# ...
#       SISTEMA DE BUSCA: HOTEL EXPLORER
# ...
# Selecione o que você deseja encontrar:
# ...
# Button(button_style='primary', description='Buscar', style=ButtonStyle())
# Output()
